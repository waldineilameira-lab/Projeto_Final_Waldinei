# %% [markdown]
# ### Analise Exploratória de Dados

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


print("Bibliotecas instaladas com sucesso!!!")
# Out:
# Bibliotecas instaladas com sucesso!!!

# %%
# Carregando o arquivo da base query 1

df = pd.read_csv("data/query_01.csv")

# %%
# Visualizando as 5 primeiras linhas do query_01. Aqui observamos as clonuas com o Id do empregado, Primeiro Nome, Sobrenome, Nome do departamento, Pais, Nome da regional, Região e Salario

df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME                      JOB_TITLE  \
# 0          205    Shelley   Higgins             Accounting Manager
# 1          206    William     Gietz              Public Accountant
# 2          101      Neena      Yang  Administration Vice President
# 3          102        Lex    Garcia  Administration Vice President
# 4          100     Steven      King                      President
#
#   DEPARTMENT_NAME  SALARY
# 0      Accounting   12008
# 1      Accounting    8300
# 2       Executive   17000
# 3       Executive   17000
# 4       Executive   24000

# %%
# Renomeado as colunas para português

df = df.rename(
    columns={
        "EMPLOYEE_ID": "id_empregado",
        "FIRST_NAME": "nome",
        "LAST_NAME": "sobrenome",
        "JOB_TITLE": "cargo",
        "DEPARTMENT_NAME": "departamento",
        "CITY": "cidade",
        "STATE_PROVINCE": "estado",
        "COUNTRY_NAME": "pais",
        "REGION_NAME": "região",
        "SALARY": "salario",
    }
)

df.head()
# Out:
#    id_empregado     nome sobrenome                          cargo  \
# 0           205  Shelley   Higgins             Accounting Manager
# 1           206  William     Gietz              Public Accountant
# 2           101    Neena      Yang  Administration Vice President
# 3           102      Lex    Garcia  Administration Vice President
# 4           100   Steven      King                      President
#
#   departamento  salario
# 0   Accounting    12008
# 1   Accounting     8300
# 2    Executive    17000
# 3    Executive    17000
# 4    Executive    24000

# %%
# Nossa base tem 58 linhas e 6 colunas.

df.shape
# Out:
# (58, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_empregado  58 non-null     int64
#  1   nome          58 non-null     object
#  2   sobrenome     58 non-null     object
#  3   cargo         58 non-null     object
#  4   departamento  57 non-null     object
#  5   salario       58 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 2.8+ KB

# %%
# Verificando se ha valores ausentes
df.isnull().sum()
# Out:
# id_empregado    0
# nome            0
# sobrenome       0
# cargo           0
# departamento    1
# salario         0
# dtype: int64

# %%
# Verificando se há valores duplicados

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[["salario"]].describe().round(2)
# Out:
#         salario
# count     58.00
# mean    9298.55
# std     3189.17
# min     5800.00
# 25%     7225.00
# 50%     8500.00
# 75%    10375.00
# max    24000.00

# %%
# Carregando o arquivo da base query 2
df2 = pd.read_csv("data/query_02.csv")
df2.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME DEPARTMENT_NAME     CITY STATE_PROVINCE  \
# 0          202        Pat     Davis       Marketing  Toronto        Ontario
# 1          201    Michael  Martinez       Marketing  Toronto        Ontario
# 2          100     Steven      King       Executive  Seattle     Washington
# 3          101      Neena      Yang       Executive  Seattle     Washington
# 4          102        Lex    Garcia       Executive  Seattle     Washington
#
#                COUNTRY_NAME REGION_NAME  SALARY
# 0                    Canada    Americas    6000
# 1                    Canada    Americas   13000
# 2  United States of America    Americas   24000
# 3  United States of America    Americas   17000
# 4  United States of America    Americas   17000

# %%
# Renomeando as colunas para português
df2 = df2.rename(columns={
    'EMPLOYEE_ID': 'id_empregado',
    'FIRST_NAME': 'nome',
    'LAST_NAME': 'sobrenome',
    'DEPARTMENT_NAME': 'departamento',
    'CITY': 'cidade',
    'STATE_PROVINCE': 'estado',
    'COUNTRY_NAME': 'pais',
    'REGION_NAME': 'regiao',
    'SALARY': 'salario'
})
df2.head()
# Out:
#    id_empregado     nome sobrenome departamento   cidade      estado  \
# 0           202      Pat     Davis    Marketing  Toronto     Ontario
# 1           201  Michael  Martinez    Marketing  Toronto     Ontario
# 2           100   Steven      King    Executive  Seattle  Washington
# 3           101    Neena      Yang    Executive  Seattle  Washington
# 4           102      Lex    Garcia    Executive  Seattle  Washington
#
#                        pais    regiao  salario
# 0                    Canada  Americas     6000
# 1                    Canada  Americas    13000
# 2  United States of America  Americas    24000
# 3  United States of America  Americas    17000
# 4  United States of America  Americas    17000

# %%
# Verificando a estrutura da base (Query 2)
df2.shape
# Out:
# (106, 9)

# %%
# Verificando valores ausentes
df2.isnull().sum()
# Out:
# id_empregado    0
# nome            0
# sobrenome       0
# departamento    0
# cidade          0
# estado          1
# pais            0
# regiao          0
# salario         0
# dtype: int64

# %%
# Verificando valores duplicados
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
df2[["salario"]].describe().round(2)
# Out:
#         salario
# count    106.00
# mean    6456.75
# std     3927.80
# min     2100.00
# 25%     3100.00
# 50%     6150.00
# 75%     8950.00
# max    24000.00

# %% [markdown]
# ### Análise Gráfica

# %%
# Histograma — distribuição geral de salários (Query 1)

plt.figure(figsize=(10, 6))
sns.histplot(df['salario'], bins=15, kde=True, color='steelblue')
plt.title('Distribuição de Salários - Query 1 (Departamento e Cargo)')
plt.xlabel('Salário (R$)')
plt.ylabel('Frequência')
plt.show()

# %%
# Boxplot — salário por departamento (Query 1)

# Boxplot de salário por departamento
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='departamento', y='salario', hue='departamento', palette='Set2', legend=False)
plt.title('Salário por Departamento')
plt.xlabel('Departamento')
plt.ylabel('Salário (R$)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Boxplot — salário por região (Query 2)

# Boxplot de salário por região
plt.figure(figsize=(10, 6))
sns.boxplot(data=df2, x='regiao', y='salario', hue='regiao', palette='Set3', legend=False)
plt.title('Salário por Região')
plt.xlabel('Região')
plt.ylabel('Salário (R$)')
plt.tight_layout()
plt.show()

# %%
# Identificando outliers de salário (Query 1) usando o método IQR

Q1 = df['salario'].quantile(0.25)
Q3 = df['salario'].quantile(0.75)
IQR = Q3 - Q1
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df[(df['salario'] < limite_inferior) | (df['salario'] > limite_superior)]
print(f"Limite inferior: {limite_inferior}")
print(f"Limite superior: {limite_superior}")
print(f"Quantidade de outliers: {len(outliers)}")
outliers
# Out:
# Limite inferior: 2500.0
# Limite superior: 15100.0
# Quantidade de outliers: 3
#    id_empregado    nome sobrenome                          cargo departamento  \
# 2           101   Neena      Yang  Administration Vice President    Executive
# 3           102     Lex    Garcia  Administration Vice President    Executive
# 4           100  Steven      King                      President    Executive
#
#    salario
# 2    17000
# 3    17000
# 4    24000

# %%
# Identificando outliers de salário (Query 2) usando o método IQR

Q1_2 = df2['salario'].quantile(0.25)
Q3_2 = df2['salario'].quantile(0.75)
IQR_2 = Q3_2 - Q1_2
limite_inferior_2 = Q1_2 - 1.5 * IQR_2
limite_superior_2 = Q3_2 + 1.5 * IQR_2

outliers_2 = df2[(df2['salario'] < limite_inferior_2) | (df2['salario'] > limite_superior_2)]
print(f"Limite inferior: {limite_inferior_2}")
print(f"Limite superior: {limite_superior_2}")
print(f"Quantidade de outliers: {len(outliers_2)}")
outliers_2
# Out:
# Limite inferior: -5675.0
# Limite superior: 17725.0
# Quantidade de outliers: 1
#    id_empregado    nome sobrenome departamento   cidade      estado  \
# 2           100  Steven      King    Executive  Seattle  Washington
#
#                        pais    regiao  salario
# 2  United States of America  Americas    24000

# %% [markdown]
# ### Gráfico de barras: Salário Médio por Departamento

# %%
# Salário médio por departamento, ordenado do maior para o menor
media_por_departamento = df.groupby('departamento')['salario'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
media_por_departamento.plot(kind='bar', color='teal')
plt.title('Salário Médio por Departamento')
plt.xlabel('Departamento')
plt.ylabel('Salário Médio (R$)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Contagem de funcionários por faixa salarial
faixas = pd.cut(df['salario'], bins=[0, 8000, 12000, 16000, 25000],
                 labels=['Até 8k', '8k-12k', '12k-16k', 'Acima de 16k'])
contagem_faixas = faixas.value_counts().sort_index()

plt.figure(figsize=(8, 5))
contagem_faixas.plot(kind='bar', color='coral')
plt.title('Distribuição de Funcionários por Faixa Salarial')
plt.xlabel('Faixa Salarial')
plt.ylabel('Quantidade de Funcionários')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
